# %%
def fibonacci(n):
    if n <= 0:
        return 0  # Base case
    elif n == 1:
        return 1  # Base case
    return fibonacci(n - 1) + fibonacci(n - 2)  # Recursive case

fibonacci(5)
# Out:
# 8

# %% [markdown]
# Let's perform a **dry run** of the Fibonacci function for `n = 5`.
#
# ---
#
# ### **Given function:**
# ```python
# def fibonacci(n):
#     if n <= 0:
#         return 0  # Base case
#     elif n == 1:
#         return 1  # Base case
#     return fibonacci(n - 1) + fibonacci(n - 2)  # Recursive case
# ```
#
# ---
#
# ### **Step-by-step dry run for `fibonacci(5)`:**
#
# 1. **First Call:** `fibonacci(5)`
#    - Condition: `n <= 0` → False
#    - Condition: `n == 1` → False
#    - Recursive calls:
#      - `fibonacci(4)`
#      - `fibonacci(3)`
#    - Expression: `fibonacci(5) = fibonacci(4) + fibonacci(3)`
#
# ---
#
# 2. **Second Call:** `fibonacci(4)`
#    - Condition: `n <= 0` → False
#    - Condition: `n == 1` → False
#    - Recursive calls:
#      - `fibonacci(3)`
#      - `fibonacci(2)`
#    - Expression: `fibonacci(4) = fibonacci(3) + fibonacci(2)`
#
# ---
#
# 3. **Third Call:** `fibonacci(3)`
#    - Condition: `n <= 0` → False
#    - Condition: `n == 1` → False
#    - Recursive calls:
#      - `fibonacci(2)`
#      - `fibonacci(1)`
#    - Expression: `fibonacci(3) = fibonacci(2) + fibonacci(1)`
#
# ---
#
# 4. **Fourth Call:** `fibonacci(2)`
#    - Condition: `n <= 0` → False
#    - Condition: `n == 1` → False
#    - Recursive calls:
#      - `fibonacci(1)`
#      - `fibonacci(0)`
#    - Expression: `fibonacci(2) = fibonacci(1) + fibonacci(0)`
#
# ---
#
# 5. **Fifth Call:** `fibonacci(1)`
#    - Condition: `n == 1` → **True**
#    - Returns `1` (Base case)
#
# ---
#
# 6. **Sixth Call:** `fibonacci(0)`
#    - Condition: `n <= 0` → **True**
#    - Returns `0` (Base case)
#
# ---
#
# Now the recursion starts **unwinding**, returning values step by step:
#
# - `fibonacci(2) = 1 + 0 = 1`
# - `fibonacci(3) = 1 + 1 = 2`
# - `fibonacci(4) = 2 + 1 = 3`
# - `fibonacci(5) = 3 + 2 = 5`
#
# ---
#
# ### **Final Answer:**
# `fibonacci(5) = 5`
#
# ---
#
# Let me know if you need further clarification! 😊
