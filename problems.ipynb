# %% [markdown]
# Section
#
# - Q Medium :
#
# - Q Easy :
#
# - Q Hard :

# %% [markdown]
# Section 1
# - Q1 (Easy): Sorted Squared Array
# https://leetcode.com/problems/squares-of-a-sorted-array/description/
#
# - Q2 (Easy): Monotonic Array
# https://leetcode.com/problems/monotonic-array/description/

# %% [markdown]
# Section 2
# - Q3 Medium : K-th Symbol in Grammar
# https://leetcode.com/problems/k-th-symbol-in-grammar/description/
# - Q4 (Medium): Josephus problem / Find the Winner of the Circular Game
# https://leetcode.com/problems/find-the-winner-of-the-circular-game/description/

# %% [markdown]
# Section 3
# - Q3 Medium : Tower Of Hanoi
# https://www.geeksforgeeks.org/problems/tower-of-hanoi-1587115621/1
# - Q4 (Medium): Power Sum
# https://www.udemy.com/course/python-data-structures-algorithms/learn/lecture/42392356#overview

# %% [markdown]
# Section 4
#
# - Q Medium : Permutations
# https://leetcode.com/problems/permutations/description/
# - Q Medium : Permutations II
# https://leetcode.com/problems/permutations-ii/description/
